# %%
import numpy as np
import pandas as pd

# %%
dogecoin = pd.read_csv("dogecoin.csv")
dogecoin["Date"] = pd.to_datetime(dogecoin["Date"])
dogecoin.set_index("Date", inplace=True)
dogecoin['momentum'] = dogecoin["Change %"].str.rstrip("%").astype("float") / 100.0
dogecoin = dogecoin.add_suffix("_DOGE")

vechain = pd.read_csv("vechain.csv")
vechain["Date"] = pd.to_datetime(vechain["Date"])
vechain.set_index("Date", inplace=True)
vechain['momentum'] = vechain["Change %"].str.rstrip("%").astype("float") / 100.0
vechain = vechain.add_suffix("_VET")

cardano = pd.read_csv("cardano.csv")
cardano["Date"] = pd.to_datetime(cardano["Date"])
cardano.set_index("Date", inplace=True)
cardano['momentum'] = cardano["Change %"].str.rstrip("%").astype("float") / 100.0
cardano = cardano.add_suffix("_ADA")

hedera_hashgraph = pd.read_csv("hedera_hashgraph.csv")
hedera_hashgraph["Date"] = pd.to_datetime(hedera_hashgraph["Date"])
hedera_hashgraph.set_index("Date", inplace=True)
hedera_hashgraph['momentum'] = hedera_hashgraph["Change %"].str.rstrip("%").astype("float") / 100.0
hedera_hashgraph = hedera_hashgraph.add_suffix("_HBAR")

litecoin = pd.read_csv("litecoin.csv")
litecoin["Date"] = pd.to_datetime(litecoin["Date"])
litecoin.set_index("Date", inplace=True)
litecoin['momentum'] = litecoin["Change %"].str.rstrip("%").astype("float") / 100.0
litecoin = litecoin.add_suffix("_LTC")

stellar = pd.read_csv("stellar.csv")
stellar["Date"] = pd.to_datetime(stellar["Date"])
stellar.set_index("Date", inplace=True)
stellar['momentum'] = stellar["Change %"].str.rstrip("%").astype("float") / 100.0
stellar = stellar.add_suffix("_XLM")

eos = pd.read_csv("eos.csv")
eos["Date"] = pd.to_datetime(eos["Date"])
eos.set_index("Date", inplace=True)
eos['momentum'] = eos["Change %"].str.rstrip("%").astype("float") / 100.0
eos = eos.add_suffix("_EOS")

tron = pd.read_csv("tron.csv")
tron["Date"] = pd.to_datetime(tron["Date"])
tron.set_index("Date", inplace=True)
tron['momentum'] = tron["Change %"].str.rstrip("%").astype("float") / 100.0
tron = tron.add_suffix("_TRX")

xrp = pd.read_csv("xrp.csv")
xrp["Date"] = pd.to_datetime(xrp["Date"])
xrp.set_index("Date", inplace=True)
xrp['momentum'] = xrp["Change %"].str.rstrip("%").astype("float") / 100.0
xrp = xrp.add_suffix("_XRP")

tether = pd.read_csv("tether.csv")
tether["Date"] = pd.to_datetime(tether["Date"])
tether.set_index("Date", inplace=True)
tether['momentum'] = tether["Change %"].str.rstrip("%").astype("float") / 100.0
tether = tether.add_suffix("_USDT")

polkadot = pd.read_csv("polkadot.csv")
polkadot["Date"] = pd.to_datetime(polkadot["Date"])
polkadot.set_index("Date", inplace=True)
polkadot['momentum'] = polkadot["Change %"].str.rstrip("%").astype("float") / 100.0
polkadot = polkadot.add_suffix("_DOT")

solana = pd.read_csv("solana.csv")
solana["Date"] = pd.to_datetime(solana["Date"])
solana.set_index("Date", inplace=True)
solana['momentum'] = solana["Change %"].str.rstrip("%").astype("float") / 100.0
solana = solana.add_suffix("_SOL")

terra = pd.read_csv("terra.csv")
terra["Date"] = pd.to_datetime(terra["Date"])
terra.set_index("Date", inplace=True)
terra['momentum'] = terra["Change %"].str.rstrip("%").astype("float") / 100.0
terra = terra.add_suffix("_LUNA")

avalanche = pd.read_csv("avalanche.csv")
avalanche["Date"] = pd.to_datetime(avalanche["Date"])
avalanche.set_index("Date", inplace=True)
avalanche['momentum'] = avalanche["Change %"].str.rstrip("%").astype("float") / 100.0
avalanche = avalanche.add_suffix("_AVAX")

theta = pd.read_csv("theta.csv")
theta["Date"] = pd.to_datetime(theta["Date"])
theta.set_index("Date", inplace=True)
theta['momentum'] = theta["Change %"].str.rstrip("%").astype("float") / 100.0
theta = theta.add_suffix("_THETA")

pancakeswap = pd.read_csv("pancakeswap.csv")
pancakeswap["Date"] = pd.to_datetime(pancakeswap["Date"])
pancakeswap.set_index("Date", inplace=True)
pancakeswap['momentum'] = pancakeswap["Change %"].str.rstrip("%").astype("float") / 100.0
pancakeswap = pancakeswap.add_suffix("_CAKE")

iota = pd.read_csv("iota.csv")
iota["Date"] = pd.to_datetime(iota["Date"])
iota.set_index("Date", inplace=True)
iota['momentum'] = iota["Change %"].str.rstrip("%").astype("float") / 100.0
iota = iota.add_suffix("_MIOTA")

uniswap = pd.read_csv("uniswap.csv")
uniswap["Date"] = pd.to_datetime(uniswap["Date"])
uniswap.set_index("Date", inplace=True)
uniswap['momentum'] = uniswap["Change %"].str.rstrip("%").astype("float") / 100.0
uniswap = uniswap.add_suffix("_UNI")

chainlink = pd.read_csv("chainlink.csv")
chainlink["Date"] = pd.to_datetime(chainlink["Date"])
chainlink.set_index("Date", inplace=True)
chainlink['momentum'] = chainlink["Change %"].str.rstrip("%").astype("float") / 100.0
chainlink = chainlink.add_suffix("_LINK")

monero = pd.read_csv("monero.csv")
monero["Date"] = pd.to_datetime(monero["Date"])
monero.set_index("Date", inplace=True)
monero['momentum'] = monero["Change %"].str.rstrip("%").astype("float") / 100.0
monero = monero.add_suffix("_XMR")

aave = pd.read_csv("aave.csv")
aave["Date"] = pd.to_datetime(aave["Date"])
aave.set_index("Date", inplace=True)
aave['momentum'] = aave["Change %"].str.rstrip("%").astype("float") / 100.0
aave = aave.add_suffix("_AAVE")

maker = pd.read_csv("maker.csv")
maker["Date"] = pd.to_datetime(maker["Date"])
maker.set_index("Date", inplace=True)
maker['momentum'] = maker["Change %"].str.rstrip("%").astype("float") / 100.0
maker = maker.add_suffix("_MKR")

dash = pd.read_csv("dash.csv")
dash["Date"] = pd.to_datetime(dash["Date"])
dash.set_index("Date", inplace=True)
dash['momentum'] = dash["Change %"].str.rstrip("%").astype("float") / 100.0
dash = dash.add_suffix("_DASH")

# %%
combined = pd.concat([dogecoin, vechain, cardano, hedera_hashgraph, litecoin, stellar, eos, tron, xrp, tether, polkadot, solana, terra, avalanche, theta, pancakeswap, iota, uniswap, chainlink, monero, aave, maker, dash], axis=1).loc[:,["momentum_DOGE", "momentum_VET", "momentum_ADA", "momentum_HBAR", "momentum_LTC", "momentum_XLM", "momentum_EOS", "momentum_TRX", "momentum_XRP", "momentum_USDT", "momentum_DOT", "momentum_SOL", "momentum_LUNA", "momentum_AVAX", "momentum_THETA", "momentum_CAKE", "momentum_MIOTA", "momentum_UNI", "momentum_LINK", "momentum_XMR", "momentum_AAVE", "momentum_MKR", "momentum_DASH"]]
combined.head()
# Out:
#             momentum_DOGE  momentum_VET  momentum_ADA  momentum_HBAR  \
# Date
# 2021-01-01         0.2133        0.0156       -0.0349         0.0346
# 2021-01-02         0.8527        0.0504        0.0131         0.0091
# 2021-01-03        -0.0609        0.3112        0.1597        -0.0120
# 2021-01-04        -0.0071       -0.0603        0.0982        -0.0091
# 2021-01-05         0.0182        0.1328        0.1452         0.1477
#
#             momentum_LTC  momentum_XLM  momentum_EOS  momentum_TRX  \
# Date
# 2021-01-01        0.0172        0.0360        0.0172        0.0032
# 2021-01-02        0.0830       -0.0355       -0.0012        0.0128
# 2021-01-03        0.1782        0.0691        0.0631        0.0830
# 2021-01-04       -0.0350        0.2026        0.0089        0.0518
# 2021-01-05        0.0187        0.1781        0.0226       -0.0795
#
#             momentum_XRP  momentum_USDT  ...  momentum_AVAX  momentum_THETA  \
# Date                                     ...
# 2021-01-01        0.0818         0.0013  ...         0.1509          0.0548
# 2021-01-02       -0.0684        -0.0015  ...        -0.0430          0.2211
# 2021-01-03        0.0173        -0.0003  ...        -0.0069         -0.1132
# 2021-01-04        0.0487         0.0000  ...         0.0380         -0.0787
# 2021-01-05       -0.0437         0.0019  ...         0.1794          0.0898
#
#             momentum_CAKE  momentum_MIOTA  momentum_UNI  momentum_LINK  \
# Date
# 2021-01-01            NaN         -0.0160       -0.0816         0.0544
# 2021-01-02            NaN         -0.0181        0.0256         0.0313
# 2021-01-03            NaN          0.0825        0.1217         0.1217
# 2021-01-04            NaN          0.1112       -0.0061        -0.0062
# 2021-01-05            NaN          0.0254        0.1546         0.0655
#
#             momentum_XMR  momentum_AAVE  momentum_MKR  momentum_DASH
# Date
# 2021-01-01       -0.1330         0.0259       -0.0076        -0.1134
# 2021-01-02        0.0568        -0.0530        0.0481        -0.0144
# 2021-01-03       -0.0366         0.0882        0.1097         0.0292
# 2021-01-04       -0.0326         0.2178        0.0165        -0.0059
# 2021-01-05        0.0176         0.0510        0.1127         0.0026
#
# [5 rows x 23 columns]

# %%
combined.to_csv('cryptocurrency_combined')
